# %%
# !pip install tensorflow_hub
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached tensorflow-2.17.0-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# ...
#   Using cached tensorflow_intel-2.17.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# ...
# Using cached tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Using cached tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.17.0-cp311-cp311-win_amd64.whl (2.0 kB)
# Using cached tensorflow_intel-2.17.0-cp311-cp311-win_amd64.whl (385.0 MB)
# ...
#   Attempting uninstall: tensorflow
# ...

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2
import PIL

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
# Out:
# WARNING:tensorflow:From C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\manda\anaconda3\envs\mlcourse301\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %%
def tensor_to_image(tensor):
  tensor = tensor*255
  tensor = np.array(tensor, dtype=np.uint8)
  if np.ndim(tensor)>3:
    assert tensor.shape[0] == 1
    tensor = tensor[0]
  return PIL.Image.fromarray(tensor)

# %%
def load_img(path_to_img):
  max_dim = 512
  img = tf.io.read_file(path_to_img)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)

  shape = tf.cast(tf.shape(img)[:-1], tf.float32)
  long_dim = max(shape)
  scale = max_dim / long_dim

  new_shape = tf.cast(shape * scale, tf.int32)

  img = tf.image.resize(img, new_shape)
  img = img[tf.newaxis, :]
  return img

# %%
def imshow(image, title=None):
  if len(image.shape) > 3:
    image = tf.squeeze(image, axis=0)

  plt.imshow(image)
  if title:
    plt.title(title)

# %%
content_image = load_img("E:/PROJECT-Art Style Transfer/data/content.png")
style_image = load_img("E:/PROJECT-Art Style Transfer/data/style2.png")

plt.subplot(1, 2, 1)
imshow(content_image, 'Content Image')

plt.subplot(1, 2, 2)
imshow(style_image, 'Style Image')

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
tensor_to_image(stylized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x372>

# %%
content_image = load_img("E:/PROJECT-Art Style Transfer/data/style1.png")
style_image = load_img("E:/PROJECT-Art Style Transfer/data/content.png")

plt.subplot(1, 2, 1)
imshow(content_image, 'Content Image')

plt.subplot(1, 2, 2)
imshow(style_image, 'Style Image')

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
tensor_to_image(stylized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x496>
